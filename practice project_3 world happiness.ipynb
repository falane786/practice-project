# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read and analysis the data

# %%
dff = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
dff
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
dff.shape
# Out:
# (158, 12)

# %%
dff.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
dff.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
dff['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
dff['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
dff.isna().count()
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# # Data analysis

# %%
dff.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
for i in dff.columns:
    print(dff[i].value_counts())
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
dff.shape
# Out:
# (158, 12)

# %%
happiness_score = dff['Happiness Score']

sns.kdeplot(happiness_score, shade=True, color='skyblue')
plt.xlabel('Happiness Score')
plt.ylabel('Density')
plt.title('Kernel Density plot of happiness score')
plt.show()

# %%
plot = plt.figure(figsize=(50,40))
sns.catplot(x='Region',data=dff, kind='count')
print(dff['Region'].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
correlation_matrix = dff.corr()

plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Divided into categorical and numerical data

# %%
categorical_col = []
for i in dff.dtypes.index:
    if dff.dtypes[i] == "object":
        categorical_col.append(i)
print("categorical columns: ", categorical_col)
print("\n")


numerical_col = []
for i in dff.dtypes.index:
    if dff.dtypes[i]!="object":
        numerical_col.append(i)
print("numerical columns: ",numerical_col)
# Out:
# categorical columns:  ['Country', 'Region']
#
#
# numerical columns:  ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
plt.figure(figsize = (25, 15), facecolor = 'white')
plotnumber = 1
for col in numerical_col:
    if plotnumber<=10:
        ax=plt.subplot(3,4, plotnumber)
        sns.distplot(dff[col],color = "m")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Happiness Rank', y='Region', data=dff)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Happiness Score', y='Region', hue='Region', data=dff)
plt.show()

# %%
sns.pairplot(dff, hue = "Happiness Score", palette = "Dark2")
plt.show()

# %% [markdown]
# # check the skewness

# %%
plt.figure(figsize = (25, 15), facecolor = 'white')
plotnumber = 1
for col in numerical_col:
    if plotnumber<=10:
        ax=plt.subplot(3,4, plotnumber)
        sns.boxplot(dff[col],color = "m")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %%
dff.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # remove the skewness

# %%
dff['Standard Error']= np.sqrt(dff['Standard Error'])
dff['Trust (Government Corruption)']= np.sqrt(dff['Trust (Government Corruption)'])
dff['Generosity']= np.sqrt(dff['Generosity'])

# %%
dff.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.225889
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
plt.figure(figsize = (25, 15), facecolor = 'white')
plotnumber = 1
for col in numerical_col:
    if plotnumber<=10:
        ax=plt.subplot(3,4, plotnumber)
        sns.distplot(dff[col],color = "m")
        plt.xlabel(col, fontsize = 15)
    plotnumber+=1
plt.show()

# %% [markdown]
# # encoded the categorical data

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_enc = OrdinalEncoder()
for i in dff.columns:
    if dff [i].dtypes=='object':
        dff[i] = ord_enc.fit_transform(dff[i].values.reshape(-1,1))
dff
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587        0.184689
# 1       58.0     9.0               2            7.561        0.220998
# 2       37.0     9.0               3            7.527        0.182428
# 3      105.0     9.0               4            7.522        0.196977
# 4       24.0     5.0               5            7.427        0.188494
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465        0.186118
# 154     13.0     8.0             155            3.340        0.191207
# 155    136.0     4.0             156            3.006        0.223942
# 156     21.0     8.0             157            2.905        0.294245
# 157    141.0     8.0             158            2.839        0.259365
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %% [markdown]
# # split the features and target veriables

# %%
X=dff.drop("Happiness Score", axis=1)
Y=dff['Happiness Score']

# %%
X
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0      135.0     9.0               1        0.184689
# 1       58.0     9.0               2        0.220998
# 2       37.0     9.0               3        0.182428
# 3      105.0     9.0               4        0.196977
# 4       24.0     5.0               5        0.188494
# ..       ...     ...             ...             ...
# 153    118.0     8.0             154        0.186118
# 154     13.0     8.0             155        0.191207
# 155    136.0     4.0             156        0.223942
# 156     21.0     8.0             157        0.294245
# 157    141.0     8.0             158        0.259365
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
Y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 1.23877001,  1.30025593, -1.72099989, ...,  1.99453385,
#          0.57205491,  0.75825809],
#        [-0.44946522,  1.30025593, -1.69907456, ...,  0.19008801,
#          1.44080569,  1.09285682],
#        [-0.90989302,  1.30025593, -1.67714922, ...,  2.30979156,
#          0.86858624,  0.71233526],
#        ...,
#        [ 1.26069514, -0.37544095,  1.67742676, ...,  0.57986048,
#          1.63848687, -3.20843049],
#        [-1.26069514,  0.96511655,  1.69935209, ..., -0.20087891,
#         -0.18313939, -0.48198451],
#        [ 1.37032081,  0.96511655,  1.72127743, ..., -0.13199882,
#         -0.45127425, -0.96361241]])

# %% [markdown]
# # train and test split

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,Y, test_size=0.27, random_state=58)
y_train.head()
# Out:
# 137    3.995
# 115    4.571
# 84     5.129
# 76     5.286
# 143    3.845
# Name: Happiness Score, dtype: float64

# %% [markdown]
# # model training

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # predict the features

# %%
dff.tail(2)
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 156     21.0     8.0             157            2.905        0.294245
# 157    141.0     8.0             158            2.839        0.259365
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 156                       0.317207    0.444151            1.83302
# 157                       0.327582    0.408424            1.56726

# %%
print('Happiness score is :',(regression.predict(scaler.transform([[21.0,8.0,157,0.294245,0.01530,0.41587,0.22396,0.11850,0.317207,0.444151,1.83302]]))))
# Out:
# Happiness score is : [2.94392385]

# %% [markdown]
# # fit the train data model

# %%
regression.score(x_train,y_train)
# Out:
# 0.9989683711573799

# %% [markdown]
# # fit the test data model

# %%
regression.score(x_test,y_test)
# Out:
# 0.9972546256795406

# %% [markdown]
# #  predict the data and visualize the plot

# %%
x_test[1]
# Out:
# array([-0.40561496,  0.2948378 , -0.12045056, -1.53658154, -0.04446317,
#         0.35370903,  0.03114413,  0.24960906, -2.30672725,  1.87121297,
#        -0.42585862])

# %%
y_pred = regression.predict(x_test)

# %%
y_pred
# Out:
# array([5.7014294 , 5.23240228, 6.30275339, 5.24586827, 5.76411184,
#        6.33193137, 5.79730577, 4.52301663, 5.38896908, 5.99060607,
#        4.26723533, 5.73234436, 4.99343785, 5.90474548, 6.70544364,
#        7.19752303, 3.93029832, 5.21546013, 4.80299585, 4.79271599,
#        5.99903924, 4.97160445, 7.32323407, 5.59022588, 5.52546891,
#        4.32250652, 4.39948369, 3.37793179, 4.49654217, 6.13274209,
#        2.94392338, 4.4931762 , 5.80070453, 6.47479953, 4.50929826,
#        5.55009152, 5.83150852, 4.31837098, 7.34929097, 6.86541819,
#        5.03028143, 6.93673479, 4.88831221])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual happiness')
plt.ylabel('Predicted happiness')
plt.title('Actual Vs prediction')
plt.show()

# %% [markdown]
# # model evaluation

# %%
y_pred = regression.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.03380753869730725

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.0027722187360741867

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.05265186355746762

# %% [markdown]
# # using lassoCV

# %%
lassocv = LassoCV(alphas = None, max_iter = 10)
lassocv.fit(x_train, y_train)
# Out:
# LassoCV(max_iter=10)

# %%
alpha = lassocv.alpha_
alpha
# Out:
# 0.0012254686420600151

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.0012254686420600151)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# 0.9975688960036163

# %%
np.arange(0.001,0.1,0.01)
# Out:
# array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091])

# %% [markdown]
# # using ridgCV

# %%
ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01))
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]))

# %%
ridgecv.alpha_
# Out:
# 0.020999999999999998

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.020999999999999998)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9972837859092408
